# %% [markdown]
# # Темы для проектов
#
# Если это соревнование:
# - 1. описать соревнование и какое было задание
# - 2. описать метрику по которой принимались решения
# - 3. описать решение
# - 4. описать результаты и что бы вы добавили
# - 5. реализовать решение и реализовать предложенные улучшения (хотя бы 1)
#
# M Competitions:
# - M4: ESRNN ([реализация в библиотеке](https://nixtlaverse.nixtla.io/neuralforecast/docs/capabilities/overview.html), тех репорт от [автора](https://github.com/slaweks17/ES_RNN/tree/master))
# - M4: NBEATS ([реализация в торче](https://pytorch-forecasting.readthedocs.io/en/v1.2.0/api/pytorch_forecasting.models.nbeats.NBeats.html), там же есть ссылки на статью)
# - M5: [uncertancy track](https://github.com/Mcompetitions/M5-methods/tree/master/Code%20of%20Winning%20Methods/U1)
# - M5: [accuracy track](https://github.com/Mcompetitions/M5-methods/tree/master/Code%20of%20Winning%20Methods/A1)
#
# - Jane Street Real-Time Market Data Forecasting [8th place](https://www.kaggle.com/competitions/jane-street-real-time-market-data-forecasting/writeups/evgeniia-grigoreva-private-lb-8th-solution)
#
#
# Если это бенчмарт:
# - 1. описать бенчмарк по которому сравниваются решения
# - 2. описать метрику по которой принимались решения
# - 3. описать SOTA решение
# - 4. описать результаты и что бы вы добавили
# - 5. реализовать решение и реализовать предложенные улучшения (хотя бы 1)
#
# Benchmarks:
# - [Forecast evaluation library](https://github.com/autogluon/fev): [leaderboard](https://huggingface.co/spaces/autogluon/fev-bench) (открылся только под vpn), SOTA = [Chronos-2: amazon foundation model](https://huggingface.co/amazon/chronos-2)
# - [OpenTS-Bench](https://github.com/decisionintelligence/TAB): [timeseries multivariate forecasting leaderboard](https://decisionintelligence.github.io/OpenTS/leaderboards/#multivariate_forecasting) (статистики открылись только под vpn), SOTA = [DUET](https://arxiv.org/pdf/2412.10859)
# - [OpenTS-Bench](https://github.com/decisionintelligence/TAB): [foundation forecasting leaderboard](https://decisionintelligence.github.io/OpenTS/leaderboards/#foundation_forecasting) (статистики открылись только под vpn), SOTA = [ROSE full](https://arxiv.org/pdf/2405.17478)
